# %% [markdown]
# <a href="https://colab.research.google.com/github/namangoyal176-10/Data-Science/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
 #question 1
a = np.random.randint(1,90,size=(5,5))
print(a)
print(np.mean (a,axis =1))
print(np.mean (a,axis =0))
print(np.where(a%2==0,-1,a))
print(np. sort(a, axis=1))
print(np. sort(a, axis=0))
print(np.sum(a,axis=0))
print(np.sum(a,axis=1))
print(np.sum(np.where(a<0,1,0),axis =0))
# Out:
# [[76 80 67 42 63]
#  [ 8 19 67 49 83]
#  [27 72 84  5 33]
#  [85 12  1  9  8]
#  [80  8 50 40 21]]
# [65.6 45.2 44.2 23.  39.8]
# [55.2 38.2 53.8 29.  41.6]
# [[-1 -1 67 -1 63]
#  [-1 19 67 49 83]
#  [27 -1 -1  5 33]
#  [85 -1  1  9 -1]
#  [-1 -1 -1 -1 21]]
# [[42 63 67 76 80]
#  [ 8 19 49 67 83]
#  [ 5 27 33 72 84]
#  [ 1  8  9 12 85]
#  [ 8 21 40 50 80]]
# [[ 8  8  1  5  8]
#  [27 12 50  9 21]
#  [76 19 67 40 33]
#  [80 72 67 42 63]
#  [85 80 84 49 83]]
# [276 191 269 145 208]
# [328 226 221 115 199]
# [0 0 0 0 0]

# %%
#question 2
a = np.random.randint(20,30,size=(5,5))
print(a)
b = np.random.randint(20,30,size=(5,5))
print(b)
c = a-b
print(c)
print(np.sum(np.where(c<0,0,0,c))
g = np.sum(np.where(c<0,c,c*-1))
print(g)
print()
k = (np.sum(np.where(a<0,0,1),axis =0))
print(k)
e = (np.sum(np.where(a<0,0,1),axis =1))
print(k+e)
# Out:
# [[21 22 25 27 24]
#  [29 28 21 27 21]
#  [23 27 23 25 26]
#  [23 21 20 26 23]
#  [28 20 20 23 21]]
# [[21 29 25 26 29]
#  [25 20 23 29 21]
#  [22 23 28 24 28]
#  [23 27 26 23 26]
#  [26 25 21 26 22]]
# [[ 0 -7  0  1 -5]
#  [ 4  8 -2 -2  0]
#  [ 1  4 -5  1 -2]
#  [ 0 -6 -6  3 -3]
#  [ 2 -5 -1 -3 -1]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3723/1969637096.py in <cell line: 0>()
#       6 c = a-b
#       7 print(c)
# ----> 8 print(np.sum(np.where(c<0,0,0),c))
#       9 g = np.sum(np.where(c<0,c,c*-1))
#      10 print(g)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2387         return res
#    2388
# -> 2389     return _wrapreduction(
#    2390         a, np.add, 'sum', axis, dtype, out,
#    2391         keepdims=keepdims, initial=initial, where=where
#
# ...

# %%
import pandas as pd
# pd is elias name

# %%
file = pd.DataFrame(pd.read_csv("./student_data.csv"))
print(file)
file = pd.read_csv("./student_data.csv", sep =',')
print(file.head(4))
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...
