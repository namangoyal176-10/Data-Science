# %% [markdown]
# <a href="https://colab.research.google.com/github/namangoyal176-10/Data-Science/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# def fun_name(parameters):
  #body of the function
def hello(a,b) :
  print(a+b); #also use return
hello(3,5)
# Out:
# 8

# %%
#lambda function
x = lambda a, b: b * a
print(x(2,3))
# Out:
# 6

# %%
x = lambda a, b: b * a
print(x(2, 3))
# Out:
# 6

# %%
x = lambda a:2*a
print(x(2))
# Out:
# 4

# %%
st = ""
print(len(st))
st = "naman goyal"
st1 = st.upper()
print(st1)
st2 = st.lower()
print(st2)
st3 = st.capitalize()
print(st3)
st4 = st.title()
print(st4)
# Out:
# 0
# NAMAN GOYAL
# naman goyal
# Naman goyal
# Naman Goyal

# %%
st = '  naman goyal.  '
#strip delete the spaces
st1 = st.strip()
print(st1)
# Out:
# naman goyal.

# %%
first = '  naman'
second  = 'goyal '
first = first.strip()
second = second.strip()
print(first+second)
# Out:
# namangoyal

# %%
a = "  today"

b = "weather  "
c = "is good. "
a = a.upper()
b = b.upper()
c = c.upper()
a = a.strip()
b = b.strip()
c = c.strip()

k = a+ " "+b+ " "+c
print(k)
# print(c)
k  = k.replace("GOOD","bad")
print(k)
k.find("WEATHER")
print(k.startswith("bad"))
print(k.count("WEATHER"))
print(k.find("WEATER"))#find return -1 if not here present
print(k.index("WEATHER")) # return error if not find
# Out:
# TODAY WEATHER IS GOOD.
# TODAY WEATHER IS bad.
# False
# 1
# -1
# 6

# %%
s = "hello world"
print(s[6:8])
print(s[6:])
print(s[:-3])
# Out:
# wo
# world
# hello wo

# %%
st = {2,4,5,2,6}
print(st)
# Out:
# {2, 4, 5, 6}

# %%
#dictornary
dic = {
    "name": ["naman","suresh"],
    "age": 30,
    "occupation" : "studet",

}
print(dic)
print(dic['name'][0])
dic['id']=12
print(dic)
del dic["name"]
print(dic)
# Out:
# {'name': ['naman', 'suresh'], 'age': 30, 'occupation': 'studet'}
# naman
# {'name': ['naman', 'suresh'], 'age': 30, 'occupation': 'studet', 'id': 12}
# {'age': 30, 'occupation': 'studet', 'id': 12}
