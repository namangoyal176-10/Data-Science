# %% [markdown]
# <a href="https://colab.research.google.com/github/namangoyal176-10/Data-Science/blob/main/class6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dct ={
    'name': ['tom','nick','krish'],
    'age': ['20','21','40'],
}
#we use the display to print
df = pd.DataFrame(dct,index=['a','b','c'])
display(df)
# Out:
#     name age
# a    tom  20
# b   nick  21
# c  krish  40

# %%
df = pd.read_csv('student_data.csv')
#head use to provide that number of line
display(df.head(3))

df.tail(3) #display last values
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62       100.0           Placed
# 1                      8              56       100.0           Placed
# 2                     10              45       100.0           Placed
#       study_hours  attendance  sleep_hours  internet_usage  \
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 9997                     10              37       95.94           Placed
# 9998                      8              52       88.61           Placed
# ...

# %%
#meta data is about a data
df.info()
#25% > is a first quartile
#50% > is a second quartile
#75% > is a third quartile
df.columns
df.index
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB
#         study_hours   attendance   sleep_hours  internet_usage  \
# count  10000.000000  10000.00000  10000.000000    10000.000000
# mean       5.989600     69.88460      6.498500        6.062600
# std        3.163589     17.61653      1.709354        3.138163
# ...

# %%
df = pd.read_csv('student_data.csv')
df[['internet_usage']]
df.study_hours
# Out:
# 0        7
# 1        4
# 2       11
# 3        8
# 4        5
#         ..
# 9995     2
# 9996     7
# 9997    10
# 9998    10
# 9999     2
# Name: study_hours, Length: 10000, dtype: int64

# %%
display(df.iloc[0:5])
#loc works on condition and iloc works on row printing
df.loc[df['study_hours'] == 11]
df2= df.loc[df['study_hours']==11]
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
df2= df.loc[df['study_hours']==11].iloc[1]
display(df2)
#this use to add new coloumn
df["age"] = 20
df
df = df.rename(columns = {'assignments_completed':'assign_completed'},inplace = True)
df
# Out:
# study_hours                  11
# attendance                   77
# sleep_hours                   4
# internet_usage                9
# assignments_completed        15
# previous_score               69
# exam_score                100.0
# placement_status         Placed
# Name: 9, dtype: object

# %%
# df[df['study_hours']>4]

# %%
#removes missing values
import pandas as pd
df = pd.read_csv('student_data.csv')

# %%
df = df.drop(2,axis =0)
display(df)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 3               8          99            9               8
# 4               5          52            8               6
# 5               7          40            9              10
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...
