# %% [markdown]
# <a href="https://colab.research.google.com/github/namangoyal176-10/Data-Science/blob/main/class8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(r'C:\Users\dell\Desktop\Hi-tech\student_data_modified.xlsx')
sns.lineplot(data=df, x='study_hours', y='exam_score', hue='placement_status')
plt.show()
sns.barplot(data=df, x='sleep_hours', y='exam_score',hue='placement_status', estimator= np.mean)
plt.show()
sns.histplot(data=df, x='attendance', hue='placement_status', bins=25)
plt.show()
sns.scatterplot(data=df, x='previous_score', y='exam_score', hue='placement_status')
plt.title('Penguin Bill Dimensions')
plt.show()
sns.boxplot(data = df, x='placement_status', y='previous_score')
plt.show()
df_heat = df[['attendance', 'assignments_completed', 'sleep_hours', 'study_hours']].corr()
sns.heatmap(df_heat, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1909/2995103302.py in <cell line: 0>()
#       4 import seaborn as sns
#       5
# ----> 6 df = pd.read_excel(r'C:\Users\dell\Desktop\Hi-tech\student_data_modified.xlsx')
#       7 sns.lineplot(data=df, x='study_hours', y='exam_score', hue='placement_status')
#       8 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
# ...
